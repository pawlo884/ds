# %% [markdown]
# # Cykl życia modelu ML / AI

# %% [markdown]
# ![](data:image/png;base64,...)

# %% [markdown]
# ## Czym jest Overfitting (Przeuczenie)?
#
# Overfitting występuje, gdy model jest zbyt dopasowany do danych treningowych i słabo generalizuje na nowe dane.
#
# ## Czym jest Underfitting (Niedouczenie)?
#
# Underfitting (niedouczenie) występuje, gdy model jest zbyt prosty, aby dobrze dopasować się do danych treningowych. W efekcie nie jest w stanie uchwycić wzorców w danych, co prowadzi do słabych wyników zarówno na danych treningowych, jak i testowych.
#
# ## Jak zbalansować dane?
# Niektóre problemy mogą mieć niezbalansowane dane (np. jeden rodzaj klasy jest znacznie liczniejszy niż inne), co może prowadzić do stronniczości modelu.
#
# - **Techniki undersampling i oversampling:** Zmniejsz liczbę przykładów w przeważającej klasie (undersampling) lub zwiększ liczbę przykładów w mniejszościowej klasie (oversampling).
# - **Użycie wag klas:** Ustaw wagi dla klas w algorytmie, aby bardziej penalizować błędy na mniej licznych klasach.
# - **Generowanie nowych przykładów:** Użyj technik takich jak SMOTE (Synthetic Minority Over-sampling Technique) do generowania nowych przykładów mniejszościowej klasy.
#
# ## Jak poprawić model?
#
# Poprawa modelu to proces iteracyjny, który obejmuje analizę wyników, dobieranie parametrów i testowanie różnych algorytmów.
#
# - **Dobieranie hiperparametrów:** Przeprowadź optymalizację hiperparametrów (np. za pomocą Grid Search lub Random Search).
# - **Ensembles:** Spróbuj połączyć wiele modeli, aby uzyskać lepsze wyniki (np. bagging, boosting).
# - **Feature engineering:** Spróbuj stworzyć nowe cechy lub zmodyfikować istniejące, aby poprawić wydajność modelu.
