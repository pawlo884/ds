# %%
import pandas as pd

# %% [markdown]
# https://matterhorn.pl/xmldata/products_full.php?type=products_csv
#
# C://Users//pawlo/Downloads/product_feed_pl_dcca48101505dd86b703689a604fe3c4.csv

# %%
df = pd.read_csv("https://matterhorn.pl/xmldata/products_full.php?type=products_csv",
                 sep=';',
                 encoding='utf-8',
                 quoting=1,  # QUOTE_ALL
                 escapechar='\\',
                 on_bad_lines='skip')
df.sample(2)
# Out:
#            id                                               name  \
# 21736  202775   Spódnica Model DHJ-SD-18760.06P Silver - Ital...
# 24172  200520        Sukienka Model AT-SK-2345-2.32 Fuksja - AT
#
#              short_name             date_add   color  \
# 21736          Spódnica  2024-10-23 00:00:00   Szary
# 24172  Sukienka dzienna  2024-09-12 00:00:00  Różowy
#
#                                              description          category  \
# 21736  Elegancka spódnica z ociepleniem, wykonana z i...          Spódnice
# 24172    Dzianinowa sukienka ołówkowa z półgolfem to ...  Sukienki Dzienne
#
#                                                   path       brand  \
# 21736                   /DLA NIEJ/Moda damska/Spódnice  Italy Moda
# 24172  /DLA NIEJ/Moda damska/Sukienki/Sukienki Dzienne          AT
#
#        wholesale_price  ...     sizes_stock  \
# 21736             77.9  ...   uniwersalny:3
# 24172             89.9  ...  S/M:15,L/XL:18
#
# ...

# %%
df.head(2)
# Out:
#        id                                               name  \
# 0  183628    Biustonosz Soft Model V-10651 Saturday night...
# 1  183695           Komplet Model V-10469 Extra Red - Axami
#
#          short_name             date_add     color  \
# 0              Soft  2023-07-28 00:00:00    Czarny
# 1  Seksowny komplet  2023-07-31 00:00:00  Czerwony
#
#                                          description  \
# 0  Koronkowa, czarna braletka absolutny bestselle...
# 1  Odkryj w sobie romantyczną nutkę w naszej efek...
#
#                              category  \
# 0  Body, Pasy, Gorsety, Figi, Leginsy
# 1                   Seksowne Komplety
#
#                                                 path  brand  wholesale_price  \
# 0  /DLA NIEJ/Bielizna damska/Bielizna erotyczna/B...  Axami             82.9
# 1  /DLA NIEJ/Bielizna damska/Bielizna erotyczna/S...  Axami             92.9
#
#    ...          sizes_stock  \
# 0  ...  s:14,M:16,L:13,XL:8
# 1  ...       s:4,L:19,XL:13
#
# ...

# %%
df.tail(4)
# Out:
#            id                                               name  \
# 34030  214221                 Bluzka Model Angel Black - Mirale
# 34031  214237                    Bluzka Model Lily Red - Mirale
# 34032  214253   Spodnie Spódnicospodnie Model Nai Pink - Mirale
# 34033  214269             Spodnie Dres Model Brav Pink - Mirale
#
#             short_name             date_add     color  \
# 34030           Bluzka  2025-05-30 00:00:00    Czarny
# 34031           Bluzka  2025-05-30 00:00:00  Czerwony
# 34032  Spódnicospodnie  2025-05-30 00:00:00    Różowy
# 34033          Komplet  2025-06-02 00:00:00    Różowy
#
#                                              description  \
# 34030  Elegancka bluzka z długim rękawem i stójką. W ...
# 34031  Bluzka Lily to połączenie wygody i romantyczne...
# 34032  Bawełniane szorty połączone ze spódniczką. Usz...
# 34033  Wygodny bawełniany komplet Brav z dzianiny dre...
#
#                       category  \
# 34030           Bluzki, Tuniki
# ...
