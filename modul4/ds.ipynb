# %%
import pandas as pd

# %% [markdown]
# https://matterhorn.pl/xmldata/products_full.php?type=products_csv
#
# C://Users//pawlo/Downloads/product_feed_pl_dcca48101505dd86b703689a604fe3c4.csv

# %%
df = pd.read_csv("https://matterhorn.pl/xmldata/products_full.php?type=products_csv",
                 sep=';',
                 encoding='utf-8',
                 quoting=1,  # QUOTE_ALL
                 escapechar='\\',
                 on_bad_lines='skip')
df.sample(2)
# Out:
#            id                                               name  \
# 27810  183948    Półbuty Model Dunadia 20148 Beige Zamsz - St...
# 3516   172804         Figi Model Tanga Cyklamen Black - Julimex
#
#                short_name             date_add   color  \
# 27810  Półbuty na obcasie  2023-08-10 00:00:00  Beżowy
# 3516    Figi brazylijskie  2022-10-28 00:00:00  Czarny
#
#                                              description         category  \
# 27810  Damskie półbuty na obcasie z cholewką wykonaną...  Botki i półbuty
# 3516   Figi CYKLAMEN TANGA to model z koronkowym tyłe...             Figi
#
#                                          path          brand  wholesale_price  \
# 27810  /DLA NIEJ/Buty damskie/Botki i półbuty  Step in style            235.9
# 3516      /DLA NIEJ/Bielizna damska/Figi/Figi        Julimex             22.9
#
#        ...          sizes_stock  \
# 27810  ...  37:3,38:2,39:3,40:2
# 3516   ...        s:1,L:12,XL:4
#
#                                                  image_1  \
# 27810  http://srv0.matterhorn.pl/db_images/custom900x...
# 3516   http://srv0.matterhorn.pl/db_images/custom900x...
#
#                                                  image_2  \
# 27810  http://srv0.matterhorn.pl/db_images/custom900x...
# 3516   http://srv0.matterhorn.pl/db_images/custom900x...
#
#                                                  image_3 image_4  \
# 27810  http://srv0.matterhorn.pl/db_images/custom900x...     NaN
# 3516                                                 NaN     NaN
#
#                                        manufacturer_id  \
# 27810  Step in style_Półbuty_Dunadia_20148_Beige_Zamsz
# 3516                 Julimex_Figi_Tanga_Cyklamen_Black
#
#                                               ean_codes       products_in_set  \
# 27810                                   37:,38:,39:,40:                   NaN
# 3516   s:5908231284815,L:5908231284808,XL:5908231284822  172804,172805,172806
#
#                       other_colors  \
# 27810  183947,183948,183949,183950
# 3516   172804,179467,185312,188534
#
#                                        sizes_sku_codes
# 27810  37:M1079696,38:M1079697,39:M1079698,40:M1079699
# 3516                 s:M1025759,L:M1025761,XL:M1025762
#
# [2 rows x 22 columns]

# %%
df.head(2)
# Out:
#        id                                               name  \
# 0  183628    Biustonosz Soft Model V-10651 Saturday night...
# 1  183695           Komplet Model V-10469 Extra Red - Axami
#
#          short_name             date_add     color  \
# 0              Soft  2023-07-28 00:00:00    Czarny
# 1  Seksowny komplet  2023-07-31 00:00:00  Czerwony
#
#                                          description  \
# 0  Koronkowa, czarna braletka absolutny bestselle...
# 1  Odkryj w sobie romantyczną nutkę w naszej efek...
#
#                              category  \
# 0  Body, Pasy, Gorsety, Figi, Leginsy
# 1                   Seksowne Komplety
#
#                                                 path  brand  wholesale_price  \
# 0  /DLA NIEJ/Bielizna damska/Bielizna erotyczna/B...  Axami             82.9
# 1  /DLA NIEJ/Bielizna damska/Bielizna erotyczna/S...  Axami             92.9
#
#    ...          sizes_stock  \
# 0  ...  s:14,M:16,L:13,XL:8
# 1  ...       s:4,L:19,XL:13
#
#                                              image_1  \
# 0  http://srv0.matterhorn.pl/db_images/custom900x...
# 1  http://srv0.matterhorn.pl/db_images/custom900x...
#
#                                              image_2 image_3 image_4  \
# 0  http://srv0.matterhorn.pl/db_images/custom900x...     NaN     NaN
# 1  http://srv0.matterhorn.pl/db_images/custom900x...     NaN     NaN
#
#                                  manufacturer_id  \
# 0  Axami_Biustonosz_V-10651_Saturday_night_Black
# 1                Axami_Komplet_V-10469_Extra_Red
#
#                                            ean_codes products_in_set  \
# 0  s:5902934964791,M:5902934964807,L:590293496481...   183625,183628
# 1   s:5902934955317,L:5902934955331,XL:5902934955348             NaN
#
#   other_colors                               sizes_sku_codes
# 0          NaN  s:M1078517,M:M1078518,L:M1078519,XL:M1078520
# 1          NaN             s:M1078814,L:M1078816,XL:M1078817
#
# [2 rows x 22 columns]

# %%
df.tail(4)
# Out:
#            id                                     name short_name  \
# 34539  214217         Bluzka Model Liz Black - Mirale      Bluzka
# 34540  214233          Bluzka Model Vera Red - Mirale      Bluzka
# 34541  214249          Szorty Model Lao Pink - Mirale      Szorty
# 34542  214265   Spodnie Dres Model Maio Pink - Mirale     Komplet
#
#                   date_add     color  \
# 34539  2025-05-30 00:00:00    Czarny
# 34540  2025-05-30 00:00:00  Czerwony
# 34541  2025-05-30 00:00:00    Różowy
# 34542  2025-06-02 00:00:00    Różowy
#
#                                              description  \
# 34539  Wiskozowa bluzka z krótkimi szyfonowymi rękawa...
# 34540  Vera to wiskozowa bluzka na naramkach w romant...
# 34541  Luźne bawełniane szorty Lao z szerokimi nogawk...
# 34542  Komplet dresowy Maio charakteryzuje się klasyc...
#
#                       category  \
# 34539           Bluzki, Tuniki
# 34540           Bluzki, Tuniki
# 34541         Szorty, rybaczki
# 34542  Spodnie, Szorty damskie
#
#                                                     path   brand  \
# 34539  /DLA NIEJ/Moda damska/Koszule, Bluzki/Bluzki, ...  Mirale
# 34540  /DLA NIEJ/Moda damska/Koszule, Bluzki/Bluzki, ...  Mirale
# 34541  /DLA NIEJ/Moda damska/Spodnie, Szorty damskie/...  Mirale
# 34542      /DLA NIEJ/Moda damska/Spodnie, Szorty damskie  Mirale
#
#        wholesale_price  ...                  sizes_stock  \
# 34539            110.9  ...  s:10,M:10,L:10,XL:10,XXL:10
# 34540             90.9  ...  s:10,M:10,L:10,XL:10,XXL:10
# 34541             96.9  ...  s:10,M:10,L:10,XL:10,XXL:10
# 34542            205.9  ...  s:10,M:10,L:10,XL:10,XXL:10
#
#                                                  image_1  \
# 34539  http://srv0.matterhorn.pl/db_images/custom900x...
# 34540  http://srv0.matterhorn.pl/db_images/custom900x...
# 34541  http://srv0.matterhorn.pl/db_images/custom900x...
# 34542  http://srv0.matterhorn.pl/db_images/custom900x...
#
#                                                  image_2  \
# 34539  http://srv0.matterhorn.pl/db_images/custom900x...
# 34540  http://srv0.matterhorn.pl/db_images/custom900x...
# 34541  http://srv0.matterhorn.pl/db_images/custom900x...
# 34542  http://srv0.matterhorn.pl/db_images/custom900x...
#
#                                                  image_3  \
# 34539  http://srv0.matterhorn.pl/db_images/custom900x...
# 34540  http://srv0.matterhorn.pl/db_images/custom900x...
# 34541  http://srv0.matterhorn.pl/db_images/custom900x...
# 34542  http://srv0.matterhorn.pl/db_images/custom900x...
#
#                                                  image_4  \
# 34539                                                NaN
# 34540  http://srv0.matterhorn.pl/db_images/custom900x...
# 34541                                                NaN
# 34542                                                NaN
#
#                manufacturer_id  \
# 34539  Mirale_Bluzka_Liz_Black
# 34540   Mirale_Bluzka_Vera_Red
# 34541   Mirale_Szorty_Lao_Pink
# 34542    Mirale_Dres_Maio_Pink
#
#                                                ean_codes products_in_set  \
# 34539  s:5902429275333,M:5902429275340,L:590242927535...             NaN
# 34540  s:5902429272851,M:5902429272868,L:590242927287...             NaN
# 34541  s:5902429273070,M:5902429273087,L:590242927309...   214229,214249
# 34542  s:5902429272288,M:5902429272295,L:590242927230...             NaN
#
#                       other_colors  \
# 34539                          NaN
# 34540  214231,214232,214233,214234
# 34541  214247,214248,214249,214250
# 34542  214263,214264,214265,214266
#
#                                          sizes_sku_codes
# 34539  s:M1226455,M:M1226456,L:M1226457,XL:M1226458,X...
# 34540  s:M1226535,M:M1226536,L:M1226537,XL:M1226538,X...
# 34541  s:M1226615,M:M1226616,L:M1226617,XL:M1226618,X...
# 34542  s:M1226695,M:M1226696,L:M1226697,XL:M1226698,X...
#
# [4 rows x 22 columns]
