# %%
import pandas as pd

# %%
df = pd.DataFrame([
    {"name": "John", "age": 25, "height": 180},
    {"name": "Jane", "age": 22, "height": 165},
    {"name": "Jim", "age": 28, "height": 175},
    {"name": "Jill", "age": 23, "height": 168},
    {"name": "Jack", "age": 27, "height": 172},
    {"name": "Jill", "age": 23, "height": 168}, 
])

df.hist()
# Out:
# array([[<Axes: title={'center': 'age'}>,
#         <Axes: title={'center': 'height'}>]], dtype=object)

# %%
df['age'].hist(bins=3)
# Out:
# <Axes: >

# %%
df.plot(kind='pie', y='age', labels=df['name'], legend=False)
# Out:
# <Axes: ylabel='age'>

# %%
df.plot(kind='bar', x='name', y=['age','height'])
# Out:
# <Axes: xlabel='name'>

# %%
df.plot(kind='scatter', x='height', y='age')
# Out:
# <Axes: xlabel='height', ylabel='age'>

# %%
df.plot(kind='box')
# Out:
# <Axes: >

# %%
df.plot?
# Out:
# Signature:      df.plot(*args, **kwargs)
# Type:           PlotAccessor
# String form:    <pandas.plotting._core.PlotAccessor object at 0x000001E6C973E590>
# File:           e:\onedrive\pulpit\kodowanie\datascientist\.venv\lib\site-packages\pandas\plotting\_core.py
# Docstring:
# Make plots of Series or DataFrame.
#
# Uses the backend specified by the
# option ``plotting.backend``. By default, matplotlib is used.
#
# Parameters
# ----------
# data : Series or DataFrame
#     The object for which the method is called.
# x : label or position, default None
#     Only used if data is a DataFrame.
# y : label, position or list of label, positions, default None
#     Allows plotting of one column versus another. Only used if data is a
#     DataFrame.
# kind : str
#     The kind of plot to produce:
#
#     - 'line' : line plot (default)
#     - 'bar' : vertical bar plot
#     - 'barh' : horizontal bar plot
#     - 'hist' : histogram
#     - 'box' : boxplot
# ...

# %%
df[['age', 'height']].corr()
# Out:
#              age    height
# age     1.000000  0.670402
# height  0.670402  1.000000
