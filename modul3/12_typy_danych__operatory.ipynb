# %% [markdown]
# # Operatory w Pythonie
#
# ## Czyli jak wykonujemy operacje na zmiennych i wartościach
#
# ![](data:image/jpeg;base64,...)

# %% [markdown]
# * Operatory to symbole, które wykorzystywane są do wykonywania konkretnych operacji na wartościach lub zmiennych.
# * Python, jak każdy język programowania, posiada kilka różnych typów operatorów.

# %% [markdown]
# ## Przykłady

# %% [markdown]
# Pierwszym typem operatorów, jakie poznamy są operatory arytmetyczne:
#
# - `+` Dodawanie
# - `-` Odejmowanie
# - `*` Mnożenie
# - `/` Dzielenie
# - `%` Modulo (reszta z dzielenia)
# - `**` Potęgowanie
# - `//` Dzielenie całkowitoliczbowe

# %%
# Dodawanie
a = 5
b = 3
print(a + b)  # Wynik: 8

# Odejmowanie
print(a - b)  # Wynik: 2

# Mnożenie
print(a * b)  # Wynik: 15

# Dzielenie
print(a / b)  # Wynik: 1.6666666666666667

# Modulo
print(a % b)  # Wynik: 2 (reszta z dzielenia 5 przez 3 to 2)

# Potęgowanie
print(a ** b)  # Wynik: 125 (5 do potęgi 3)

# Dzielenie całkowitoliczbowe
print(a // b)  # Wynik: 1 (dzielenie bez reszty)

# %% [markdown]
# ### Operatory porównania
# Służą do porównywania wartości, zwracają `True` lub `False`.
#
# - `==` Równe
# - `!=` Różne
# - `<` Mniejsze niż
# - `>` Większe niż
# - `<=` Mniejsze lub równe
# - `>=` Większe lub równe
#
# Przykłady:

# %%
a = 5
b = 3

# Równe
print(a == b)  # Wynik: False

# Różne
print(a != b)  # Wynik: True

# Mniejsze niż
print(a < b)  # Wynik: False

# Większe niż
print(a > b)  # Wynik: True

# Mniejsze lub równe
print(a <= b)  # Wynik: False

# Większe lub równe
print(a >= b)  # Wynik: True

# %% [markdown]
# ### Operatory przypisania
# Używane do przypisywania wartości do zmiennych.
#
# - `=` Przypisanie
# - `+=` Dodawanie i przypisanie
# - `-=` Odejmowanie i przypisanie
# - `*=` Mnożenie i przypisanie
# - `/=` Dzielenie i przypisanie
# - `%=` Modulo i przypisanie
# - `**=` Potęgowanie i przypisanie
# - `//=` Dzielenie całkowitoliczbowe i przypisanie
#
# Przykłady:

# %%
a = 5

# Dodawanie i przypisanie
a += 3  # Równoważne z a = a + 3
print(a)  # Wynik: 8

# Odejmowanie i przypisanie
a -= 2  # Równoważne z a = a - 2
print(a)  # Wynik: 6

# Mnożenie i przypisanie
a *= 2  # Równoważne z a = a * 2
print(a)  # Wynik: 12

# Dzielenie i przypisanie
a /= 3  # Równoważne z a = a / 3
print(a)  # Wynik: 4.0

# Modulo i przypisanie
a %= 3  # Równoważne z a = a % 3
print(a)  # Wynik: 1.0

# Potęgowanie i przypisanie
a **= 2  # Równoważne z a = a ** 2
print(a)  # Wynik: 1.0

# Dzielenie całkowitoliczbowe i przypisanie
a //= 1  # Równoważne z a = a // 1
print(a)  # Wynik: 1.0

# %% [markdown]
# ### Operatory logiczne
# Służą do łączenia warunków logicznych.
#
# - `and` Logiczne "i"
# - `or` Logiczne "lub"
# - `not` Logiczne "nie"
#
# Przykłady:

# %%
a = True
b = False

# Logiczne "i"
print(a and b)  # Wynik: False

# Logiczne "lub"
print(a or b)  # Wynik: True

# Logiczne "nie"
print(not a)  # Wynik: False

# %% [markdown]
# ### Operatory tożsamościowe
# Służą do sprawdzania, czy dwie zmienne odnoszą się do tego samego obiektu.
#
# - `is` Tożsamy z
# - `is not` Nie tożsamy z
#
# Przykłady:

# %%
a = [1, 2, 3]
b = a
c = [1, 2, 3]

# Tożsamy z
print(a is b)  # Wynik: True
print(a is c)  # Wynik: False

# Nie tożsamy z
print(a is not c)  # Wynik: True

# %% [markdown]
# ### Operatory przynależności
# Służą do sprawdzania, czy wartość znajduje się w innej wartości (np. w liście).
#
# - `in` Zawiera się
# - `not in` Nie zawiera się
#
# Przykłady:

# %%
a = [1, 2, 3]

# Zawiera się
print(2 in a)  # Wynik: True

# Nie zawiera się
print(4 not in a)  # Wynik: True

# %% [markdown]
# ## Najczęściej pojawiające się błędy

# %% [markdown]
# ### Dzielimy przez zero
# Błąd `ZeroDivisionError` pojawia się, gdy próbujemy podzielić liczbę przez zero.

# %%
# Błąd: ZeroDivisionError
result = 10 / 0

# %% [markdown]
# **Wyjaśnienie:** W matematyce dzielenie przez zero jest niedozwolone.

# %% [markdown]
# ### Łączenie różnych typów danych
# Błąd `TypeError` może się pojawić, gdy próbujemy użyć operatora na dwóch różnych typach danych, które się nie zgadzają.

# %%
# Błąd: TypeError
number = 10
text = "Hello"
result = number + text

# %% [markdown]
# **Wyjaśnienie:** Python nie wie, jak zsumować liczbę (`number`) i tekst (`text`). Można to poprawić np. konwertując liczbę na tekst za pomocą `str()`.

# %%
number = 10
text = "Hello"
result = text + str(number)  # poprawione

# %% [markdown]
# ### Operacje na niezdefiniowanych zmiennych
# Błąd `NameError` pojawia się, gdy próbujemy użyć zmiennej, która nie została zdefiniowana.

# %%
# Błąd: NameError
result = aa + 5

# %% [markdown]
# **Wyjaśnienie:** Zmienna `a` nie została wcześniej zdefiniowana.

# %% [markdown]
# ### Błędy w operacjach logicznych
# Błędy logiczne mogą występować, jeśli nie jesteśmy ostrożni w pisaniu warunków.

# %%
# Błąd logiczny
age = 18
if age = 18:
    print("You are 18 years old.")

# %% [markdown]
# **Wyjaśnienie:** Użyto `=` zamiast `==` (operator przypisania zamiast operatora porównania). Poprawny kod to:

# %%
age = 18
if age == 18:
    print("You are 18 years old.")

# %% [markdown]
# ### Zamiana typu danych nieodpowiedniego do operacji arytmetycznych
# Próba wykonania operacji arytmetycznych na danych, które nie są liczbami, może również prowadzić do `TypeError`.

# %%
# Błąd: TypeError
result = "5" + 10

# %% [markdown]
# **Wyjaśnienie:** Python nie wie, jak dodać ciąg znaków ("5") do liczby całkowitej (10). Można to poprawić za pomocą konwersji typu danych.

# %%
result = int("5") + 10  # poprawione

# %% [markdown]
# ### Operacje na `None`
#
# Próba wykonania operacji arytmetycznych z wartością `None` również prowadzi do `TypeError`.

# %%
# Błąd: TypeError
x = None
result = x + 5

# %% [markdown]
# **Wyjaśnienie:** `None` nie jest liczbą, więc operacja arytmetyczna jest niedozwolona.
