# %% [markdown]
# # Instrukcje warunkowe w Pythonie
#
# ## Czyli jak podejmować decyzje
#
# ![](data:image/jpeg;base64,...)

# %% [markdown]
# * Instrukcja warunkowa `if` w Pythonie służy do wykonywania kodu tylko wtedy, gdy spełniony jest określony warunek.
# * Najprostsza forma instrukcji `if` wygląda tak:
#
# ```python
# if warunek:
#     # kod, który będzie wykonany, gdy warunek jest prawdziwy
# ```

# %% [markdown]
# ### Jak to działa?
#
# 1. Python sprawdza warunek podany za `if`.
# 2. Jeśli warunek jest prawdziwy (`True`), wykonuje kod znajdujący się w bloku poniżej.
# 3. Jeśli warunek jest fałszywy (`False`), Python ignoruje ten blok kodu i przechodzi do kodu po instrukcji.

# %% [markdown]
# ## Przykłady

# %% [markdown]
# ### Sprawdzanie, czy liczba jest dodatnia
#
# Wyobraźmy sobie, że chcemy napisać program, który sprawdzi, czy liczba jest dodatnia:

# %%
number = 5

if number > 0:
    print("Liczba jest dodatnia!")

# %% [markdown]
# ### Sprawdzanie wieku
#
# Załóżmy, że chcemy sprawdzić, czy osoba jest pełnoletnia (czyli ma co najmniej 18 lat):

# %%
age = 20

if age >= 18:
    print("Jesteś pełnoletni!")

# %% [markdown]
# ### Rozbudowane instrukcje warunkowe: `if`, `elif`, `else`
#
# Instrukcja `if` może być rozszerzona o `elif` (else if), która pozwala sprawdzać dodatkowe warunki, oraz `else`, które wykonuje kod, gdy żaden z wcześniejszych warunków nie jest spełniony.

# %% [markdown]
# ### Sprawdzanie temperatury
#
# Napiszmy program, który klasyfikuje temperaturę:

# %%
temperature = 30

if temperature > 30:
    print("Jest gorąco!")
elif temperature >= 15:
    print("Jest ciepło!")
else:
    print("Jest zimno!")

# %% [markdown]
# Tutaj:
# - Jeśli `temperature` jest większa niż 30, drukowane jest "Jest gorąco!"
# - Jeśli `temperature` jest większa lub równa 15 (ale nie większa niż 30), drukowane jest "Jest ciepło!"
# - Jeśli żaden z powyższych warunków nie jest spełniony, drukowane jest "Jest zimno!"

# %% [markdown]
# ### Sprawdzanie loginu i hasła
#
# Na koniec stwórzmy prosty system logowania:

# %%
login = "admin"
password = "password123"

if login == "admin" and password == "password123":
    print("Logowanie udane!")
else:
    print("Błędny login lub hasło.")

# %% [markdown]
# Tutaj program sprawdza, czy `login` i `password` są równe określonym wartościom. Jeśli oba warunki są spełnione, drukowane jest "Logowanie udane!", w przeciwnym razie drukowane jest "Błędny login lub hasło."

# %% [markdown]
# ## Przykłady błędów

# %% [markdown]
# ### Literówki i błędy składniowe
#
# Jednym z najczęstszych błędów są literówki lub błędy składniowe.

# %%
# Błąd: Literówka w słowie `printt`
if 5 > 3:
    printt("5 is greater than 3")

# %% [markdown]
# ### Zapomniana dwukropka
#
# W instrukcjach warunkowych często zapomina się o dwukropku (`:`) na końcu linii `if`, `elif` lub `else`.

# %%
# Błąd: Brak dwukropka na końcu `if`
if 5 > 3
    print("5 is greater than 3")

# %% [markdown]
# ### Błędny format wcięć
#
# Python wymaga stosowania wcięć, a błąd wcięć może sprawić, że kod stanie się nieczytelny lub nieprawidłowy.

# %%
# Błąd: Niewłaściwe wcięcia
if 5 > 3:
print("5 is greater than 3")
  print("Still true")

# %% [markdown]
# ### Użycie nawiasów w warunkach
#
# Choć Python nie wymaga nawiasów w warunkach, może to prowadzić do błędów.

# %%
# Błąd: Nawiasy nie są używane poprawnie
if (5 > 3))
    print("5 is greater than 3")

# %% [markdown]
# ### Tworzenie złożonych warunków
#
# Złożone warunki mogą prowadzić do błędów logicznych, jeśli nie są prawidłowo sformatowane.

# %%
# Błąd: Niewłaściwe użycie operatorów logicznych
x = 5
y = 10

if x > 2 and y < 8 or y > 12:
    print("Condition met")

# %% [markdown]
# W tym przypadku, może ci się wydawać, że wiesz, co robi ten kod, ale logika może być skomplikowana. Użycie nawiasów dla jasności jest kluczowe.

# %%
# Poprawnie: Użycie nawiasów dla jasności
if (x > 2 and (y < 8 or y > 12)):
    print("Condition met")

# %% [markdown]
# ### Porównania z błędnymi typami danych
#
# Porównywanie wartości różnych typów danych może prowadzić do nieoczekiwanych wyników.

# %%
# Błąd: Porównanie liczby całkowitej z napisem
if 5 == "5":
    print("5 is equal to '5'")

# %% [markdown]
# ### Mylące przypisanie zamiast porównania
#
# Użycie pojedynczego znaku równości (`=`) zamiast podwójnego (`==`) przez przypadek.

# %%
# Błąd: Przypisanie zamiast porównania
x = 5
if x = 3:
    print("x is 3")

# %% [markdown]
# Powinno być:

# %%
# Poprawnie: Użycie podwójnego znaku równości do porównania
x = 5
if x == 3:
    print("x is 3")
