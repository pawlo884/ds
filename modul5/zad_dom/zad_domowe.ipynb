# %% [markdown]
# # Zadanie domowe - łączenie danych!
#
# Wykonujesz zlecenia dla firmy, która chce żebyśmy połączyli dane z trzech różnych źródeł.
#
# 1. Pierwsze źródło danych to dane o klientach. Na szczęście zespół, który zajmuje się klientami, wie co robi i wszystkie dane dostępne są w bazie danych (`zad_domowe__clients.db` w tabeli `clients`).
# 2. Drugie źródło danych to dane o produktach. W tym przypadku dane dostępne są w pliku CSV (`zad_domowe__products.csv`).
# 3. Ostatnie źródło danych to dane o zamówieniach / fakturach. Tutaj niestety mamy problem. Okazuje się, że klient wszystkie faktury ma w postaci zrzutów z ekranu (pliki `zad_domowe__invoice_1.png`, `zad_domowe__invoice_2.png` etc.).
#
# Twoim zadaniem jest połączenie tych danych w jeden plik CSV, który będzie zawierał informacje o kliencie, produkcie i fakturze. Przygotuj plik CSV, który zawiera tylko niezbędne kolumny, nie ma żadnych kolumn powtórzonych.
#
# Jak rezultat wyciągania danych z faktur chcemy mieć w każdym wierszu informacje o zakupionym produkcie, ilości, kliencie, cenie jednostkowej.
#
# Początek kodu znajdziesz w tym notebooku.

# %%
from pathlib import Path
import pandas as pd
import sqlite3
import base64
from datetime import date
import instructor
from pydantic import BaseModel
from IPython.display import Image
from openai import OpenAI
import os
from dotenv import load_dotenv

# %%
# będziemy potrzebować klucza API do OpenAI żeby odczytać dane z faktur

load_dotenv()
openai_key = os.getenv("OPENAI_API_KEY")
openai_client = OpenAI(api_key=openai_key)

# %% [markdown]
# ## Czytamy dane klientów

# %%
with sqlite3.connect("zad_domowe__clients.db") as conn:
    clients_df = pd.read_sql_query("SELECT * FROM clients", conn)

clients_df.head()
# Out:
#    id             name                       email                  phone
# 0   1     Carla Ramsey        frypeter@example.net    (508)998-5166x12326
# 1   2     Howard Mcgee  jacobpatterson@example.org   001-669-353-6118x978
# 2   3       Eric Moore         lejacob@example.org           923-681-4646
# 3   4      Laura Beard   westdominique@example.org          (291)558-0966
# 4   5  Joshua Santiago    sheilamedina@example.com  +1-929-417-0571x74051

# %% [markdown]
# ## Czytamy dane produktów

# %%
# TUTAJ WPISZ SWÓJ KOD
products_df = pd.read_csv("zad_domowe__products.csv", sep=";")

products_df.head()
# Out:
#    id       name  price
# 0   1  telewizor     85
# 1   2     laptop     47
# 2   3   smartfon     60
# 3   4     tablet     40
# 4   5  słuchawki     40

# %% [markdown]
# ## Czytamy dane faktur

# %%
# na szczęście mamy już strukturę którą chcemy pobrać z faktur
class InvoiceInfoItem(BaseModel):
    description: str
    product_id: int
    quantity: int
    price: float


class InvoiceInfo(BaseModel):
    company_name: str
    customer_id: int
    customer_name: str
    invoice_number: int
    date: date
    # mamy tutaj do czynienia z listą elementów, więc danymi zagnieżdżonymi!
    items: list[InvoiceInfoItem]


RAW_DATA_PATH = Path("raw_inv")

instructor_openai_client = instructor.from_openai(OpenAI(api_key=openai_key))
orders = []
for image_path in sorted(RAW_DATA_PATH.glob("zad_domowe__invoice_*.png")):
    print(f"Processing {image_path}")
    with open(image_path, "rb") as f:
        image_data = base64.b64encode(f.read()).decode('utf-8')

    # UWAGA! tutaj brakuje kodu!!! Co powinniśmy tutaj zrobić?
    invoice_info = instructor_openai_client.chat.completions.create(
        model="gpt-4o-mini",
        temperature=0,
        response_model=InvoiceInfo,
        messages=[
            {
                "role": "user",
                "content": [
                    {
                        "type": "text",
                        "text": "Odczytaj informacje z faktury i zwróć je w podanym poniżej formacie InvoiceInfo."
                    },
                    {
                        "type": "image_url",
                        "image_url": {
                            "url": f"data:image/png;base64,{image_data}",
                            "detail": "high"
                        }
                    }
                ]
            }
        ]
    )

    invoice_data = invoice_info.model_dump()
    for item in invoice_data["items"]:
        order = {
            "company_name": invoice_data["company_name"],
            "customer_id": invoice_data["customer_id"],
            "customer_name": invoice_data["customer_name"],
            "invoice_number": invoice_data["invoice_number"],
            "date": invoice_data["date"],
            "description": item["description"],
            "product_id": item["product_id"],
            "quantity": item["quantity"],
            "price": item["price"],
        }
        orders.append(order)

orders_df = pd.DataFrame(orders)
# Out:
# Processing raw_inv\zad_domowe__invoice_1.png
# Processing raw_inv\zad_domowe__invoice_10.png
# Processing raw_inv\zad_domowe__invoice_2.png
# Processing raw_inv\zad_domowe__invoice_3.png
# Processing raw_inv\zad_domowe__invoice_4.png
# Processing raw_inv\zad_domowe__invoice_5.png
# Processing raw_inv\zad_domowe__invoice_6.png
# Processing raw_inv\zad_domowe__invoice_7.png
# Processing raw_inv\zad_domowe__invoice_8.png
# Processing raw_inv\zad_domowe__invoice_9.png

# %%
orders_df = pd.DataFrame(orders)
orders_df.head(10)
# Out:
#   company_name  customer_id      customer_name  invoice_number        date  \
# 0    Firma XYZ            3         Eric Moore               2  2024-05-25
# 1    Firma XYZ            3         Eric Moore               2  2024-05-25
# 2    Firma XYZ           92    Valerie Stevens              11  2024-05-02
# 3    Firma XYZ           60     Troy Alexander               3  2024-05-19
# 4    Firma XYZ           78  William Velazquez               4  2024-03-26
# 5    Firma XYZ           33     Steven Jackson               5  2024-07-23
# 6    Firma XYZ           33     Steven Jackson               5  2024-07-23
# 7    Firma XYZ            8    Ronald Callahan               6  2024-03-14
# 8    Firma XYZ            8    Ronald Callahan               6  2024-03-14
# 9    Firma XYZ            4        Laura Beard               7  2024-06-24
#
#                  description  product_id  quantity  price
# 0                     router           7         3   48.0
# 1                      narty          17         5   55.0
# 2                  słuchawki           5         1   40.0
# 3                ochraniacze          16         4   46.0
# 4                      rolki          14         3   11.0
# 5  pendrive (id produktu 10)          10         4   47.0
# 6     laptop (id produktu 2)           2         2   47.0
# 7                  słuchawki           5         4   40.0
# 8                ochraniacze          16         2   46.0
# 9  telewizor (id produktu 1)           1         2   85.0

# %% [markdown]
# ## Łączenie danych

# %%
# merge clients and orders
company_df = pd.merge(    
    clients_df,
    orders_df,
    left_on='id',
    right_on= 'customer_id',
    how='right')
company_df.head(100)
# Out:
#      id               name                        email                 phone  \
# 0     3         Eric Moore          lejacob@example.org          923-681-4646
# 1     3         Eric Moore          lejacob@example.org          923-681-4646
# 2    92    Valerie Stevens            xlowe@example.com    757-943-1579x98346
# 3    60     Troy Alexander          nturner@example.net   +1-212-349-3992x430
# 4    78  William Velazquez           lisa25@example.net     (765)602-1572x949
# 5    33     Steven Jackson         jeremy07@example.com          481.258.2434
# 6    33     Steven Jackson         jeremy07@example.com          481.258.2434
# 7     8    Ronald Callahan         audrey56@example.com   +1-727-668-2720x085
# 8     8    Ronald Callahan         audrey56@example.com   +1-727-668-2720x085
# 9     4        Laura Beard    westdominique@example.org         (291)558-0966
# 10   63     Alexis Johnson  campbellkatrina@example.org         (311)679-3346
# 11   63     Alexis Johnson  campbellkatrina@example.org         (311)679-3346
# 12   63     Alexis Johnson  campbellkatrina@example.org         (311)679-3346
# 13  100    Johnny Franklin        bankslisa@example.org   (626)681-2730x71696
# 14   44   Kimberly Marquez         joseph28@example.net  +1-688-249-5941x6260
# 15   44   Kimberly Marquez         joseph28@example.net  +1-688-249-5941x6260
#
#    company_name  customer_id      customer_name  invoice_number        date  \
# 0     Firma XYZ            3         Eric Moore               2  2024-05-25
# 1     Firma XYZ            3         Eric Moore               2  2024-05-25
# 2     Firma XYZ           92    Valerie Stevens              11  2024-05-02
# 3     Firma XYZ           60     Troy Alexander               3  2024-05-19
# 4     Firma XYZ           78  William Velazquez               4  2024-03-26
# 5     Firma XYZ           33     Steven Jackson               5  2024-07-23
# 6     Firma XYZ           33     Steven Jackson               5  2024-07-23
# 7     Firma XYZ            8    Ronald Callahan               6  2024-03-14
# 8     Firma XYZ            8    Ronald Callahan               6  2024-03-14
# 9     Firma XYZ            4        Laura Beard               7  2024-06-24
# 10    Firma XYZ           63     Alexis Johnson               8  2024-02-21
# 11    Firma XYZ           63     Alexis Johnson               8  2024-02-21
# 12    Firma XYZ           63     Alexis Johnson               8  2024-02-21
# 13    Firma XYZ          100    Johnny Franklin               9  2024-01-26
# 14    Firma XYZ           44   Kimberly Marquez              10  2024-03-14
# 15    Firma XYZ           44   Kimberly Marquez              10  2024-03-14
#
#                   description  product_id  quantity  price
# 0                      router           7         3   48.0
# 1                       narty          17         5   55.0
# 2                   słuchawki           5         1   40.0
# 3                 ochraniacze          16         4   46.0
# 4                       rolki          14         3   11.0
# 5   pendrive (id produktu 10)          10         4   47.0
# 6      laptop (id produktu 2)           2         2   47.0
# 7                   słuchawki           5         4   40.0
# 8                 ochraniacze          16         2   46.0
# 9   telewizor (id produktu 1)           1         2   85.0
# 10                 klawiatura           9         1   65.0
# 11                     router           7         1   48.0
# 12                    spodnie          20         1   14.0
# 13                    spodnie          20         2   14.0
# 14                     laptop           2         1   47.0
# 15                 klawiatura           9         2   65.0

# %%
# merge clients&orders and products
company_df = pd.merge(
    company_df,
    products_df,
    left_on='product_id',
    right_on='id',
    how='left')
company_df.head(100).sort_values(by='id_x')
# Out:
#     id_x             name_x                        email  \
# 0      3         Eric Moore          lejacob@example.org
# 1      3         Eric Moore          lejacob@example.org
# 9      4        Laura Beard    westdominique@example.org
# 7      8    Ronald Callahan         audrey56@example.com
# 8      8    Ronald Callahan         audrey56@example.com
# 5     33     Steven Jackson         jeremy07@example.com
# 6     33     Steven Jackson         jeremy07@example.com
# 14    44   Kimberly Marquez         joseph28@example.net
# 15    44   Kimberly Marquez         joseph28@example.net
# 3     60     Troy Alexander          nturner@example.net
# 10    63     Alexis Johnson  campbellkatrina@example.org
# 11    63     Alexis Johnson  campbellkatrina@example.org
# 12    63     Alexis Johnson  campbellkatrina@example.org
# 4     78  William Velazquez           lisa25@example.net
# 2     92    Valerie Stevens            xlowe@example.com
# 13   100    Johnny Franklin        bankslisa@example.org
#
#                    phone company_name  customer_id      customer_name  \
# 0           923-681-4646    Firma XYZ            3         Eric Moore
# 1           923-681-4646    Firma XYZ            3         Eric Moore
# 9          (291)558-0966    Firma XYZ            4        Laura Beard
# 7    +1-727-668-2720x085    Firma XYZ            8    Ronald Callahan
# 8    +1-727-668-2720x085    Firma XYZ            8    Ronald Callahan
# 5           481.258.2434    Firma XYZ           33     Steven Jackson
# 6           481.258.2434    Firma XYZ           33     Steven Jackson
# 14  +1-688-249-5941x6260    Firma XYZ           44   Kimberly Marquez
# 15  +1-688-249-5941x6260    Firma XYZ           44   Kimberly Marquez
# 3    +1-212-349-3992x430    Firma XYZ           60     Troy Alexander
# 10         (311)679-3346    Firma XYZ           63     Alexis Johnson
# 11         (311)679-3346    Firma XYZ           63     Alexis Johnson
# 12         (311)679-3346    Firma XYZ           63     Alexis Johnson
# 4      (765)602-1572x949    Firma XYZ           78  William Velazquez
# 2     757-943-1579x98346    Firma XYZ           92    Valerie Stevens
# 13   (626)681-2730x71696    Firma XYZ          100    Johnny Franklin
#
#     invoice_number        date                description  product_id  \
# 0                2  2024-05-25                     router           7
# 1                2  2024-05-25                      narty          17
# 9                7  2024-06-24  telewizor (id produktu 1)           1
# 7                6  2024-03-14                  słuchawki           5
# 8                6  2024-03-14                ochraniacze          16
# 5                5  2024-07-23  pendrive (id produktu 10)          10
# 6                5  2024-07-23     laptop (id produktu 2)           2
# 14              10  2024-03-14                     laptop           2
# 15              10  2024-03-14                 klawiatura           9
# 3                3  2024-05-19                ochraniacze          16
# 10               8  2024-02-21                 klawiatura           9
# 11               8  2024-02-21                     router           7
# 12               8  2024-02-21                    spodnie          20
# 4                4  2024-03-26                      rolki          14
# 2               11  2024-05-02                  słuchawki           5
# 13               9  2024-01-26                    spodnie          20
#
#     quantity  price_x  id_y       name_y  price_y
# 0          3     48.0     7       router       48
# 1          5     55.0    17        narty       55
# 9          2     85.0     1    telewizor       85
# 7          4     40.0     5    słuchawki       40
# 8          2     46.0    16  ochraniacze       46
# 5          4     47.0    10     pendrive       47
# 6          2     47.0     2       laptop       47
# 14         1     47.0     2       laptop       47
# 15         2     65.0     9   klawiatura       65
# 3          4     46.0    16  ochraniacze       46
# 10         1     65.0     9   klawiatura       65
# 11         1     48.0     7       router       48
# 12         1     14.0    20      spodnie       14
# 4          3     11.0    14        rolki       11
# 2          1     40.0     5    słuchawki       40
# 13         2     14.0    20      spodnie       14

# %%
company_df = (
    company_df
    .drop(columns=["customer_id", "customer_name", "id_y", 'price_y','description'])
    .rename(columns={
        'id_x' : 'ID klienta',
        'name_x': 'Nazwa klienta',
        'company_name' : 'Nazwa firmy',
        'invoice_number' : 'Numer faktury',
        'date' : 'Data faktury',
        'description' : 'Opis',
        'product_id' : 'ID produktu',
        'quantity' : 'Ilość',
        'price_x' : 'Cena',
        'email' : 'Email',
        'phone' : 'Telefon',
        'name_y' : 'Nazwa produktu',
    })
)
company_df.head(100).sort_values(by='ID klienta')
# Out:
#     ID klienta      Nazwa klienta                        Email  \
# 0            3         Eric Moore          lejacob@example.org
# 1            3         Eric Moore          lejacob@example.org
# 9            4        Laura Beard    westdominique@example.org
# 7            8    Ronald Callahan         audrey56@example.com
# 8            8    Ronald Callahan         audrey56@example.com
# 5           33     Steven Jackson         jeremy07@example.com
# 6           33     Steven Jackson         jeremy07@example.com
# 14          44   Kimberly Marquez         joseph28@example.net
# 15          44   Kimberly Marquez         joseph28@example.net
# 3           60     Troy Alexander          nturner@example.net
# 10          63     Alexis Johnson  campbellkatrina@example.org
# 11          63     Alexis Johnson  campbellkatrina@example.org
# 12          63     Alexis Johnson  campbellkatrina@example.org
# 4           78  William Velazquez           lisa25@example.net
# 2           92    Valerie Stevens            xlowe@example.com
# 13         100    Johnny Franklin        bankslisa@example.org
#
#                  Telefon Nazwa firmy  Numer faktury Data faktury  ID produktu  \
# 0           923-681-4646   Firma XYZ              2   2024-05-25            7
# 1           923-681-4646   Firma XYZ              2   2024-05-25           17
# 9          (291)558-0966   Firma XYZ              7   2024-06-24            1
# 7    +1-727-668-2720x085   Firma XYZ              6   2024-03-14            5
# 8    +1-727-668-2720x085   Firma XYZ              6   2024-03-14           16
# 5           481.258.2434   Firma XYZ              5   2024-07-23           10
# 6           481.258.2434   Firma XYZ              5   2024-07-23            2
# 14  +1-688-249-5941x6260   Firma XYZ             10   2024-03-14            2
# 15  +1-688-249-5941x6260   Firma XYZ             10   2024-03-14            9
# 3    +1-212-349-3992x430   Firma XYZ              3   2024-05-19           16
# 10         (311)679-3346   Firma XYZ              8   2024-02-21            9
# 11         (311)679-3346   Firma XYZ              8   2024-02-21            7
# 12         (311)679-3346   Firma XYZ              8   2024-02-21           20
# 4      (765)602-1572x949   Firma XYZ              4   2024-03-26           14
# 2     757-943-1579x98346   Firma XYZ             11   2024-05-02            5
# 13   (626)681-2730x71696   Firma XYZ              9   2024-01-26           20
#
#     Ilość  Cena Nazwa produktu
# 0       3  48.0         router
# 1       5  55.0          narty
# 9       2  85.0      telewizor
# 7       4  40.0      słuchawki
# 8       2  46.0    ochraniacze
# 5       4  47.0       pendrive
# 6       2  47.0         laptop
# 14      1  47.0         laptop
# 15      2  65.0     klawiatura
# 3       4  46.0    ochraniacze
# 10      1  65.0     klawiatura
# 11      1  48.0         router
# 12      1  14.0        spodnie
# 4       3  11.0          rolki
# 2       1  40.0      słuchawki
# 13      2  14.0        spodnie

# %%
company_df = company_df[['ID klienta', 'Nazwa klienta', 'Email', 'Telefon', 'Nazwa firmy', 'Numer faktury', 'Data faktury', 'ID produktu','Nazwa produktu', 'Ilość', 'Cena']]

# company_df = company_df.sort_values(by='ID klienta')

company_df.head(100)
company_df.to_csv('zad_domowe__orders.csv', sep=';', index=True)
