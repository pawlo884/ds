# %% [markdown]
# # Aplikacja Notatki Audio

# %% [markdown]
# ## Specyfikacja / Specs
#
# Użytkownik ma możliwość:
# * Nagrać notatkę audio.
# * Odtworzyć notatkę audio.
# * Transkrybować notatkę audio.
# * Zapisać notatkę audio w bazie danych.
# * Odczytać notatkę audio z bazy danych.

# %% [markdown]
# ## Architektura
#
# ![](data:image/png;base64,...)

# %% [markdown]
# ## Plan / Taski
# * v1 - nagrywanie i odtwarzanie głosu.
# * v2 - transkrypcja tekstu.
# * v3 - ochrona klucza openai
# * v4 - odświeżanie aplikacji po nagraniu nowego audio
# * v5 - zapisywanie tekstu i embeddings w bazie danych
# * v6 - wyszukiwanie notatek

# %% [markdown]
# ## Zależności
# * `streamlit` - do budowy interfejsu użytkownika.
# * zewnętrznego komponentu `audiorecorder`  `streamlit-audiorecorder` (https://github.com/theevann/streamlit-audiorecorder)
# * `openai` i modelu `whisper-1` - do transkrypcji tekstu.
# * `dotenv` - do przechowywania klucza openai.
# * `openai` i modelu `text-embedding-3-large` - do uzyskania embeddings tekstu.
# * `qdrant` - do przechowywania i wyszukiwania tekstu i embeddings (jako bazy danych).

# %% [markdown]
# ## Umiejętności
#
# * `streamlit` - moduł 6
# * `dotenv` - moduł 6
# * `openai embeddings` - moduły 7
# * `openai whisper` - moduły 7
# * `pydub` - moduł 7
# * `io` - moduł 7
# * `md5` - moduł 7
# * `qdrant` - moduł 7

# %% [markdown]
# ## Instalujemy wymagane biblioteki (conda wymagana)
#
# - otwórz terminal
# - uruchom `conda activate od_zera_do_ai`
# - uruchom `conda config --append channels conda-forge`
# - uruchom `conda install -y streamlit ffmpeg pydub qdrant-client openai python-dotenv`
# - uruchom `pip install streamlit-audiorecorder`

# %% [markdown]
# ##
