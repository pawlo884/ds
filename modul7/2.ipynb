# %%
from io import BytesIO
from pydub import AudioSegment

# %%
bio = BytesIO()

bio.write(b"Hello, world!")

bio.seek(0)

print(bio.read())
# Out:
# b'Hello, world!'

# %%
segment = AudioSegment.from_file("audio_about_ai.wav", format="wav")
segment
# Out:
#                     <audio controls>
#                         <source src="data:audio/mpeg;base64,..." type="audio/mpeg"/>
#                         Your browser does not support the audio element.
#                     </audio>

# %%
segment.export("audio_about_ai.mp3", format="mp3")
# Out:
# <_io.BufferedRandom name='audio_about_ai.mp3'>

# %%
audio = BytesIO()
segment.export(audio, format="mp3")

# %%
audio.seek(0)
print(audio.read()[:20])
# Out:
# b'ID3\x04\x00\x00\x00\x00\x00"TSSE\x00\x00\x00\x0e\x00\x00'
